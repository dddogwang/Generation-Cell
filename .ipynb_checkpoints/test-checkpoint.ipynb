# %%
import keras
from keras import layers
from keras.backend import tensorflow_backend as K
import numpy as np
import os
import PIL.Image as Image
from keras.preprocessing import image
import cv2,os
import numpy as np
from matplotlib import pyplot as plt

latent_dim = 100
height = 32
width = 32
channels = 3
col = 5
row = 5
image_size = 32
save_dir = './out'

# %%
def wasserstein(y_true, y_pred):
    return K.mean(y_true * y_pred)


def Conv_Down(x, kernel_size, channel, name='Conv_Down?_'):
    # x = layers.BatchNormalization(axis=-1, name=name + 'BN')(x)
    x = layers.Conv2D(channel, kernel_size, strides=2, padding='same', name=name+'Conv1',
                      kernel_initializer=keras.initializers.RandomNormal(stddev=0.02))(x)
    x = layers.LeakyReLU(0.2, name=name+'LeakyReLU1')(x)
    # x = layers.Dropout(0.2)(x)
    # x = layers.Conv2D(channel, kernel_size, padding='same', name=name + 'Conv2',
    #                   kernel_initializer=keras.initializers.RandomNormal(stddev=0.02))(x)
    # x = layers.LeakyReLU(0.2, name=name + 'LeakyReLU2')(x)
    return x


def Conv_Up(x, kernel_size, channel, name='Conv_Down?_'):
    x = layers.Conv2DTranspose(channel, kernel_size, strides=2, padding='same', name=name+'ConvT',
                      kernel_initializer=keras.initializers.RandomNormal(stddev=0.02))(x)
    x = layers.BatchNormalization(axis=-1, name=name+'BN')(x)
    # x = layers.LeakyReLU(0.2, name=name + 'LeakyReLU1')(x)
    x = layers.ReLU(name=name + 'ReLU')(x)
    return x


def G_net():
    generator_input = keras.Input(shape=(latent_dim,), name='G_input')
    x = layers.Dense(512 * 4 * 4, name='G_First_Dense',
                     kernel_initializer=keras.initializers.RandomNormal(stddev=0.02))(generator_input)
    x = layers.Reshape((4, 4, 512))(x)
    x = layers.BatchNormalization(name='G_BN0')(x)
    x = layers.ReLU(name='G_ReLU')(x)
    x = Conv_Up(x, kernel_size=5, channel=256, name='Conv_Up1_')
    # x = layers.BatchNormalization(name='G_BN1')(x)
    x = Conv_Up(x, kernel_size=5, channel=128, name='Conv_Up2_')
    # x = layers.BatchNormalization(name='G_BN2')(x)
    # x = Conv_Up(x, kernel_size=3, channel=128, name='Conv_Up3_')
    x = layers.Conv2DTranspose(channels, 5, activation='tanh', strides=2, padding='same', name='G_output',
                               kernel_initializer=keras.initializers.RandomNormal(stddev=0.02))(x)    # 输出层
    generator = keras.models.Model(generator_input, x, name='G')
    generator.summary()
    return generator


def D_net():
    discriminator_input = layers.Input(shape=(height, width, channels), name='D_input')
    # x = layers.Conv2D(64, 3, padding='same', name='D_First_Conv')(discriminator_input)
    # # x = layers.BatchNormalization(name='D_First_BN')(x)
    # x = layers.LeakyReLU()(x)
    x = Conv_Down(discriminator_input, kernel_size=5, channel=128, name='Conv_Down1_')
    x = layers.Dropout(0.3)(x)
    x = Conv_Down(x, kernel_size=5, channel=256, name='Conv_Down2_')
    x = layers.Dropout(0.3)(x)
    x = Conv_Down(x, kernel_size=5, channel=512, name='Conv_Down3_')
    x = layers.Flatten()(x)
    x = layers.Dropout(0.3)(x)
    x = layers.Dense(1, activation='sigmoid', name='D_output')(x)
    discriminator = keras.models.Model(discriminator_input, x, name='D')
    discriminator.summary()
    # discriminator_optimizer = keras.optimizers.RMSprop(lr=0.0001, clipvalue=1.0, decay=1e-8)
    discriminator_optimizer = keras.optimizers.Adam(lr=0.0002, beta_1=0.5)
    discriminator.compile(optimizer=discriminator_optimizer,
                          loss='binary_crossentropy')
    return discriminator


# G和D的网络结构
G = G_net()
D = D_net()
# G.load_weights(save_dir+'/G_3.5w.h5', by_name=True)
# D.load_weights(save_dir+'/D_3.5w.h5', by_name=True)
# G, D, WGAN = WGAN_net()
# G和D的训练方法
D.trainable = False
WGAN_input = keras.Input(shape=(latent_dim,))
WGAN_output = D(G(WGAN_input))
WGAN = keras.models.Model(WGAN_input, WGAN_output)
WGAN.summary()
# WGAN_optimizer = keras.optimizers.RMSprop(lr=0.0002, clipvalue=1.0, decay=1e-8)
WGAN_optimizer = keras.optimizers.Adam(lr=0.0004, beta_1=0.5)
WGAN.compile(optimizer=WGAN_optimizer, loss='binary_crossentropy')
# WGAN.load_weights(save_dir+'/WGAN_3.5w.h5', by_name=True)


# 定义图像拼接函数
def image_compose(ori_images, save_path):
    imgs = []
    for i in range(col * row):
        imgs.append(image.array_to_img((ori_images[i]+1) * 127.5, scale=False))
    to_image = Image.new('RGB', (col * image_size, row * image_size))   #创建一个新图
    # 循环遍历，把每张图片按顺序粘贴到对应位置上
    for y in range(row):
        for x in range(col):
            from_image = imgs[y*col+x].resize((image_size, image_size), Image.ANTIALIAS)
            to_image.paste(from_image, (x * image_size, y * image_size))
    return to_image.save(save_path)  # 保存新图
# Out:
# WARNING:tensorflow:From /home/acd13264yb/jupyter_env/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py:541: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# WARNING:tensorflow:From /home/acd13264yb/jupyter_env/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py:4409: The name tf.random_normal is deprecated. Please use tf.random.normal instead.
#
# WARNING:tensorflow:From /home/acd13264yb/jupyter_env/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py:66: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# WARNING:tensorflow:From /home/acd13264yb/jupyter_env/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py:190: The name tf.get_default_session is deprecated. Please use tf.compat.v1.get_default_session instead.
#
# WARNING:tensorflow:From /home/acd13264yb/jupyter_env/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py:197: The name tf.ConfigProto is deprecated. Please use tf.compat.v1.ConfigProto instead.
#
# WARNING:tensorflow:From /home/acd13264yb/jupyter_env/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py:2041: The name tf.nn.fused_batch_norm is deprecated. Please use tf.compat.v1.nn.fused_batch_norm instead.
#
# Model: "G"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# G_input (InputLayer)         (None, 100)               0
# _________________________________________________________________
# G_First_Dense (Dense)        (None, 8192)              827392
# _________________________________________________________________
# reshape_1 (Reshape)          (None, 4, 4, 512)         0
# _________________________________________________________________
# G_BN0 (BatchNormalization)   (None, 4, 4, 512)         2048
# _________________________________________________________________
# G_ReLU (ReLU)                (None, 4, 4, 512)         0
# _________________________________________________________________
# Conv_Up1_ConvT (Conv2DTransp (None, 8, 8, 256)         3277056
# _________________________________________________________________
# Conv_Up1_BN (BatchNormalizat (None, 8, 8, 256)         1024
# _________________________________________________________________
# Conv_Up1_ReLU (ReLU)         (None, 8, 8, 256)         0
# _________________________________________________________________
# Conv_Up2_ConvT (Conv2DTransp (None, 16, 16, 128)       819328
# _________________________________________________________________
# Conv_Up2_BN (BatchNormalizat (None, 16, 16, 128)       512
# _________________________________________________________________
# Conv_Up2_ReLU (ReLU)         (None, 16, 16, 128)       0
# _________________________________________________________________
# G_output (Conv2DTranspose)   (None, 32, 32, 3)         9603
# =================================================================
# Total params: 4,936,963
# Trainable params: 4,935,171
# Non-trainable params: 1,792
# _________________________________________________________________
# WARNING:tensorflow:From /home/acd13264yb/jupyter_env/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py:3733: calling dropout (from tensorflow.python.ops.nn_ops) with keep_prob is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `rate` instead of `keep_prob`. Rate should be set to `rate = 1 - keep_prob`.
# Model: "D"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# D_input (InputLayer)         (None, 32, 32, 3)         0
# _________________________________________________________________
# Conv_Down1_Conv1 (Conv2D)    (None, 16, 16, 128)       9728
# _________________________________________________________________
# Conv_Down1_LeakyReLU1 (Leaky (None, 16, 16, 128)       0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 16, 16, 128)       0
# _________________________________________________________________
# Conv_Down2_Conv1 (Conv2D)    (None, 8, 8, 256)         819456
# _________________________________________________________________
# Conv_Down2_LeakyReLU1 (Leaky (None, 8, 8, 256)         0
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 8, 8, 256)         0
# _________________________________________________________________
# Conv_Down3_Conv1 (Conv2D)    (None, 4, 4, 512)         3277312
# _________________________________________________________________
# Conv_Down3_LeakyReLU1 (Leaky (None, 4, 4, 512)         0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 8192)              0
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 8192)              0
# _________________________________________________________________
# D_output (Dense)             (None, 1)                 8193
# =================================================================
# Total params: 4,114,689
# Trainable params: 4,114,689
# Non-trainable params: 0
# _________________________________________________________________
# WARNING:tensorflow:From /home/acd13264yb/jupyter_env/lib/python3.6/site-packages/keras/optimizers.py:793: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.
#
# WARNING:tensorflow:From /home/acd13264yb/jupyter_env/lib/python3.6/site-packages/tensorflow/python/ops/nn_impl.py:180: add_dispatch_support.<locals>.wrapper (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# Model: "model_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         (None, 100)               0
# _________________________________________________________________
# G (Model)                    (None, 32, 32, 3)         4936963
# _________________________________________________________________
# D (Model)                    (None, 1)                 4114689
# =================================================================
# Total params: 9,051,652
# Trainable params: 4,935,171
# Non-trainable params: 4,116,481
# _________________________________________________________________

# %%
# DCGAN的训练
(x_train, y_train), (_, _) = keras.datasets.cifar10.load_data()
x_train = x_train[y_train.flatten() == 1]   # car
x_train = x_train.reshape((x_train.shape[0],) + (height, width, channels)).astype('float32') / 127.5 - 1
iterations = 10000
batch_size = 64
start = 0
for step in range(iterations):
    # Samples random points in the latent space
    random_latent_vectors = np.random.normal(size=(batch_size, latent_dim))
    # Decodes them to fake images
    G_images = G.predict(random_latent_vectors)
    # Combines them with real images
    stop = start + batch_size
    real_images = x_train[start: stop]
    combined_images = np.concatenate([G_images, real_images])
    # Assembles labels, discriminating real from fake images
    labels = np.concatenate([0.90*np.ones((batch_size, 1)),
                             np.zeros((batch_size, 1))])
    # 为标签添加随机噪音————这是一个重要的技巧！
    labels += 0.05 * np.random.random(labels.shape)+0.05
    for i in range(1):
        d_loss = D.train_on_batch(combined_images, labels)
 
    # Samples random points in the Assembles latent space
    random_latent_vectors = np.random.normal(size=(batch_size, latent_dim))
    # Assembles latent space labels that say “these are all real images” (it’s a lie!)
    misleading_targets = np.zeros((batch_size, 1))
    for i in range(1):
        a_loss = WGAN.train_on_batch(random_latent_vectors, misleading_targets)
    # a_loss = WGAN.train_on_batch(random_latent_vectors, misleading_targets)
    start += batch_size
    if start > len(x_train) - batch_size:
        start = 0
    # Occasionally saves and plots (every 100 steps)
    # print('step:', step, '/', iterations, '------', round(100 * step / iterations, 3), '%',
    #       '-- discriminator loss:', d_loss, '-- adversarial loss:', a_loss)
    if step % 125 == 0:
        if d_loss < 0: break
        print('step:', step, '/', iterations, '------', round(100 * step / iterations, 3), '%',
              '-- discriminator loss:', d_loss, '-- adversarial loss:', a_loss)
        if step < 5000 or step % 625 == 0:
            image_compose(G_images, os.path.join(save_dir, 'generated_pic' + str(step) + '.png'))
    if step % 5000 == 0:
        G.save(save_dir + '/G_' + str(step / 10000) + 'w.h5')
        D.save(save_dir + '/D_' + str(step / 10000) + 'w.h5')
        WGAN.save(save_dir + '/WGAN_' + str(step / 10000) + 'w.h5')
    if step % 10000 == 0:
        image_compose(real_images, os.path.join(save_dir, 'real_pic' + str(step) + '.png'))
G.save('./G_END.h5')
D.save('./D_END.h5')
WGAN.save('./WGAN_END.h5')
# Out:
# /home/acd13264yb/jupyter_env/lib/python3.6/site-packages/keras/engine/training.py:493: UserWarning: Discrepancy between trainable weights and collected trainable weights, did you set `model.trainable` without calling `model.compile` after ?
#   'Discrepancy between trainable weights and collected trainable'
# step: 0 / 10000 ------ 0.0 % -- discriminator loss: 0.70476234 -- adversarial loss: 0.5410315
# /home/acd13264yb/jupyter_env/lib/python3.6/site-packages/keras/engine/training.py:493: UserWarning: Discrepancy between trainable weights and collected trainable weights, did you set `model.trainable` without calling `model.compile` after ?
#   'Discrepancy between trainable weights and collected trainable'
# step: 125 / 10000 ------ 1.25 % -- discriminator loss: 0.417912 -- adversarial loss: 3.3712728
# step: 250 / 10000 ------ 2.5 % -- discriminator loss: 0.59360075 -- adversarial loss: 1.4098753
# step: 375 / 10000 ------ 3.75 % -- discriminator loss: 0.5809561 -- adversarial loss: 1.0580616
# step: 500 / 10000 ------ 5.0 % -- discriminator loss: 0.68045497 -- adversarial loss: 1.1433309
# step: 625 / 10000 ------ 6.25 % -- discriminator loss: 0.68267316 -- adversarial loss: 1.6121657
# step: 750 / 10000 ------ 7.5 % -- discriminator loss: 0.6112926 -- adversarial loss: 0.93646455
# step: 875 / 10000 ------ 8.75 % -- discriminator loss: 0.6664545 -- adversarial loss: 0.90336496
# step: 1000 / 10000 ------ 10.0 % -- discriminator loss: 0.45732015 -- adversarial loss: 2.071391
# step: 1125 / 10000 ------ 11.25 % -- discriminator loss: 0.53745556 -- adversarial loss: 1.4434347
# step: 1250 / 10000 ------ 12.5 % -- discriminator loss: 0.78609693 -- adversarial loss: 1.5189652
# step: 1375 / 10000 ------ 13.75 % -- discriminator loss: 0.71062696 -- adversarial loss: 1.238398
# step: 1500 / 10000 ------ 15.0 % -- discriminator loss: 0.5843363 -- adversarial loss: 1.7337127
# step: 1625 / 10000 ------ 16.25 % -- discriminator loss: 0.7428536 -- adversarial loss: 0.67003226
# step: 1750 / 10000 ------ 17.5 % -- discriminator loss: 0.6841431 -- adversarial loss: 0.9316467
# step: 1875 / 10000 ------ 18.75 % -- discriminator loss: 0.6947768 -- adversarial loss: 1.6520795
# step: 2000 / 10000 ------ 20.0 % -- discriminator loss: 0.55452013 -- adversarial loss: 1.4569788
# step: 2125 / 10000 ------ 21.25 % -- discriminator loss: 0.8596526 -- adversarial loss: 2.415166
# step: 2250 / 10000 ------ 22.5 % -- discriminator loss: 0.7083394 -- adversarial loss: 1.620067
# step: 2375 / 10000 ------ 23.75 % -- discriminator loss: 0.6222147 -- adversarial loss: 1.9617369
# step: 2500 / 10000 ------ 25.0 % -- discriminator loss: 0.60668695 -- adversarial loss: 1.9907147
# step: 2625 / 10000 ------ 26.25 % -- discriminator loss: 0.50214654 -- adversarial loss: 1.8597131
# step: 2750 / 10000 ------ 27.5 % -- discriminator loss: 0.6689782 -- adversarial loss: 1.962774
# step: 2875 / 10000 ------ 28.75 % -- discriminator loss: 0.57868016 -- adversarial loss: 1.3308203
# step: 3000 / 10000 ------ 30.0 % -- discriminator loss: 0.48026666 -- adversarial loss: 1.6677573
# step: 3125 / 10000 ------ 31.25 % -- discriminator loss: 0.56935203 -- adversarial loss: 1.6075819
# step: 3250 / 10000 ------ 32.5 % -- discriminator loss: 0.67837 -- adversarial loss: 1.108155
# step: 3375 / 10000 ------ 33.75 % -- discriminator loss: 0.7045561 -- adversarial loss: 1.6318518
# step: 3500 / 10000 ------ 35.0 % -- discriminator loss: 0.5353992 -- adversarial loss: 1.0709822
# step: 3625 / 10000 ------ 36.25 % -- discriminator loss: 0.5794289 -- adversarial loss: 1.5473529
# step: 3750 / 10000 ------ 37.5 % -- discriminator loss: 0.6540191 -- adversarial loss: 1.4276382
# step: 3875 / 10000 ------ 38.75 % -- discriminator loss: 0.6447172 -- adversarial loss: 1.3385086
# step: 4000 / 10000 ------ 40.0 % -- discriminator loss: 0.45946044 -- adversarial loss: 1.6542549
# step: 4125 / 10000 ------ 41.25 % -- discriminator loss: 0.5543535 -- adversarial loss: 1.5033768
# step: 4250 / 10000 ------ 42.5 % -- discriminator loss: 0.70868295 -- adversarial loss: 0.58890873
# step: 4375 / 10000 ------ 43.75 % -- discriminator loss: 0.62407357 -- adversarial loss: 1.4636638
# step: 4500 / 10000 ------ 45.0 % -- discriminator loss: 0.62557495 -- adversarial loss: 3.9662957
# step: 4625 / 10000 ------ 46.25 % -- discriminator loss: 0.53589386 -- adversarial loss: 2.8985515
# step: 4750 / 10000 ------ 47.5 % -- discriminator loss: 0.48876292 -- adversarial loss: 0.6718901
# step: 4875 / 10000 ------ 48.75 % -- discriminator loss: 0.541946 -- adversarial loss: 2.1288
# step: 5000 / 10000 ------ 50.0 % -- discriminator loss: 0.44040704 -- adversarial loss: 1.9963939
# step: 5125 / 10000 ------ 51.25 % -- discriminator loss: 0.37404144 -- adversarial loss: 0.899354
# step: 5250 / 10000 ------ 52.5 % -- discriminator loss: 0.59564066 -- adversarial loss: 1.5100784
# step: 5375 / 10000 ------ 53.75 % -- discriminator loss: 0.49765378 -- adversarial loss: 0.8475827
# step: 5500 / 10000 ------ 55.0 % -- discriminator loss: 0.6344215 -- adversarial loss: 1.5502236
# step: 5625 / 10000 ------ 56.25 % -- discriminator loss: 0.73543906 -- adversarial loss: 1.260283
# step: 5750 / 10000 ------ 57.5 % -- discriminator loss: 0.4584284 -- adversarial loss: 0.91519713
# step: 5875 / 10000 ------ 58.75 % -- discriminator loss: 0.5585791 -- adversarial loss: 1.6917975
# step: 6000 / 10000 ------ 60.0 % -- discriminator loss: 0.45460248 -- adversarial loss: 2.4093359
# step: 6125 / 10000 ------ 61.25 % -- discriminator loss: 0.67115873 -- adversarial loss: 3.5794194
# step: 6250 / 10000 ------ 62.5 % -- discriminator loss: 0.63862795 -- adversarial loss: 3.1006575
# step: 6375 / 10000 ------ 63.75 % -- discriminator loss: 0.6482874 -- adversarial loss: 3.0062397
# step: 6500 / 10000 ------ 65.0 % -- discriminator loss: 0.75270855 -- adversarial loss: 0.7170373
# step: 6625 / 10000 ------ 66.25 % -- discriminator loss: 0.5340702 -- adversarial loss: 1.9225028
# step: 6750 / 10000 ------ 67.5 % -- discriminator loss: 0.70888007 -- adversarial loss: 1.0851562
# step: 6875 / 10000 ------ 68.75 % -- discriminator loss: 0.49595308 -- adversarial loss: 0.7386022
# step: 7000 / 10000 ------ 70.0 % -- discriminator loss: 0.61628044 -- adversarial loss: 1.1335608
# step: 7125 / 10000 ------ 71.25 % -- discriminator loss: 0.59389603 -- adversarial loss: 1.2899842
# step: 7250 / 10000 ------ 72.5 % -- discriminator loss: 0.46449924 -- adversarial loss: 1.0874747
# step: 7375 / 10000 ------ 73.75 % -- discriminator loss: 0.48133105 -- adversarial loss: 1.4593763
# step: 7500 / 10000 ------ 75.0 % -- discriminator loss: 0.5663831 -- adversarial loss: 1.7919062
# step: 7625 / 10000 ------ 76.25 % -- discriminator loss: 0.5469041 -- adversarial loss: 1.1213295
# step: 7750 / 10000 ------ 77.5 % -- discriminator loss: 0.5025507 -- adversarial loss: 1.19191
# step: 7875 / 10000 ------ 78.75 % -- discriminator loss: 0.7529678 -- adversarial loss: 2.637224
# step: 8000 / 10000 ------ 80.0 % -- discriminator loss: 0.49736094 -- adversarial loss: 1.6620154
# step: 8125 / 10000 ------ 81.25 % -- discriminator loss: 0.80426836 -- adversarial loss: 0.9589752
# step: 8250 / 10000 ------ 82.5 % -- discriminator loss: 0.67306614 -- adversarial loss: 1.2380797
# step: 8375 / 10000 ------ 83.75 % -- discriminator loss: 0.53885627 -- adversarial loss: 0.83789325
# step: 8500 / 10000 ------ 85.0 % -- discriminator loss: 0.48894188 -- adversarial loss: 1.5695693
# step: 8625 / 10000 ------ 86.25 % -- discriminator loss: 0.51567024 -- adversarial loss: 1.4862747
# step: 8750 / 10000 ------ 87.5 % -- discriminator loss: 0.7113383 -- adversarial loss: 3.8604975
# step: 8875 / 10000 ------ 88.75 % -- discriminator loss: 0.7714975 -- adversarial loss: 1.8013172
# step: 9000 / 10000 ------ 90.0 % -- discriminator loss: 0.69982505 -- adversarial loss: 2.24613
# step: 9125 / 10000 ------ 91.25 % -- discriminator loss: 0.5526309 -- adversarial loss: 1.9451413
# step: 9250 / 10000 ------ 92.5 % -- discriminator loss: 0.603925 -- adversarial loss: 1.4185852
# step: 9375 / 10000 ------ 93.75 % -- discriminator loss: 0.50083244 -- adversarial loss: 2.6029868
# step: 9500 / 10000 ------ 95.0 % -- discriminator loss: 0.63398767 -- adversarial loss: 1.4678909
# step: 9625 / 10000 ------ 96.25 % -- discriminator loss: 0.74641323 -- adversarial loss: 1.1650956
# step: 9750 / 10000 ------ 97.5 % -- discriminator loss: 0.57000726 -- adversarial loss: 1.6564038
# step: 9875 / 10000 ------ 98.75 % -- discriminator loss: 0.54243535 -- adversarial loss: 2.0420914

# %%
# %ls "./out/"
# Out:
# D_0.0w.h5               generated_pic17500.png  generated_pic3875.png
# D_0.5w.h5               generated_pic1750.png   generated_pic4000.png
# D_1.0w.h5               generated_pic18125.png  generated_pic4125.png
# D_1.5w.h5               generated_pic18750.png  generated_pic4250.png
# D_2.0w.h5               generated_pic1875.png   generated_pic4375.png
# D_2.5w.h5               generated_pic19375.png  generated_pic4500.png
# G_0.0w.h5               generated_pic20000.png  generated_pic4625.png
# G_0.5w.h5               generated_pic2000.png   generated_pic4750.png
# G_1.0w.h5               generated_pic20625.png  generated_pic4875.png
# G_1.5w.h5               generated_pic21250.png  generated_pic5000.png
# G_2.0w.h5               generated_pic2125.png   generated_pic500.png
# G_2.5w.h5               generated_pic21875.png  generated_pic5625.png
# generated_frog0.png     generated_pic22500.png  generated_pic6250.png
# generated_frog100.png   generated_pic2250.png   generated_pic625.png
# generated_frog200.png   generated_pic23125.png  generated_pic6875.png
# generated_frog300.png   generated_pic23750.png  generated_pic7500.png
# generated_pic0.png      generated_pic2375.png   generated_pic750.png
# generated_pic10000.png  generated_pic24375.png  generated_pic8125.png
# generated_pic1000.png   generated_pic25000.png  generated_pic8750.png
# generated_pic10625.png  generated_pic2500.png   generated_pic875.png
# generated_pic11250.png  generated_pic250.png    generated_pic9375.png
# generated_pic1125.png   generated_pic25625.png  real_frog0.png
# generated_pic11875.png  generated_pic26250.png  real_frog100.png
# generated_pic12500.png  generated_pic2625.png   real_frog200.png
# generated_pic1250.png   generated_pic26875.png  real_frog300.png
# generated_pic125.png    generated_pic27500.png  real_pic0.png
# generated_pic13125.png  generated_pic2750.png   real_pic10000.png
# generated_pic13750.png  generated_pic2875.png   real_pic20000.png
# generated_pic1375.png   generated_pic3000.png   WGAN_0.0w.h5
# generated_pic14375.png  generated_pic3125.png   WGAN_0.5w.h5
# generated_pic15000.png  generated_pic3250.png   WGAN_1.0w.h5
# generated_pic1500.png   generated_pic3375.png   WGAN_1.5w.h5
# generated_pic15625.png  generated_pic3500.png   WGAN_2.0w.h5
# generated_pic16250.png  generated_pic3625.png   WGAN_2.5w.h5
# generated_pic1625.png   generated_pic3750.png
# generated_pic16875.png  generated_pic375.png

# %%
plt.figure()
plt.imshow(cv2.imread("./out/generated_pic27500.png"))
