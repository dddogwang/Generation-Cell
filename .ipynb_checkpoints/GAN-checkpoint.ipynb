# %% [markdown]
# # Data

# %%
path = "../Datasets/210901PictData/Cell01/1_488_conf_gamma6/1_488_conf_gamma6_"

data = []
# fig, ax = plt.subplots(2,2, figsize = (40,40))
i=0
while i < 36:
    filepath = path+str(i)+".tif"
    img=cv2.imread(filepath)
    if 100<=img.shape[0]<=512 and 400<=img.shape[1]<=512:
        print(filepath)
        data.append(img)
#         plt.figure(figsize=(8,8))
#         plt.imshow(img)
#         plt.show()
#         plt.subplot(6,6,i+1)
#         plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))
    i+=1
    
    
DataResize=[]

Max_shape_0 = 512
Max_shape_1 = 512

for img in data:
    imgSize = img.shape
    
    top_size,bottom_size = (Max_shape_0-imgSize[0])//2,(Max_shape_0-imgSize[0])//2
    left_size,right_size = (Max_shape_1-imgSize[1])//2,(Max_shape_1-imgSize[1])//2
    
    if (imgSize[0] % 2) != 0:
        top_size,bottom_size = (Max_shape_0-imgSize[0])//2,(Max_shape_0-imgSize[0])//2+1
        
    if (imgSize[1] % 2) != 0:     
        left_size,right_size = (Max_shape_1-imgSize[1])//2,(Max_shape_1-imgSize[1])//2+1
    
    img_pad = cv2.copyMakeBorder(img,top_size,bottom_size,left_size,right_size,cv2.BORDER_CONSTANT,value=(0,0,0))
  
    DataResize.append(img_pad)

print("DataResize: ",len(DataResize))
# Out:
# ../Datasets/210901PictData/Cell01/1_488_conf_gamma6/1_488_conf_gamma6_0.tif
# ../Datasets/210901PictData/Cell01/1_488_conf_gamma6/1_488_conf_gamma6_4.tif
# ../Datasets/210901PictData/Cell01/1_488_conf_gamma6/1_488_conf_gamma6_10.tif
# ../Datasets/210901PictData/Cell01/1_488_conf_gamma6/1_488_conf_gamma6_13.tif
# ../Datasets/210901PictData/Cell01/1_488_conf_gamma6/1_488_conf_gamma6_17.tif
# ../Datasets/210901PictData/Cell01/1_488_conf_gamma6/1_488_conf_gamma6_18.tif
# ../Datasets/210901PictData/Cell01/1_488_conf_gamma6/1_488_conf_gamma6_20.tif
# ../Datasets/210901PictData/Cell01/1_488_conf_gamma6/1_488_conf_gamma6_27.tif
# DataResize:  8

# %%
for img in DataResize:
    plt.figure(figsize=(8,8))
    plt.imshow(img)
    plt.show()

# %%
DataResize = np.array(DataResize)

# %% [markdown]
# # G_net

# %%
import keras
from keras import layers
import numpy as np

latent_dim = 2
height = 512
width = 512
channels = 3
generator_input = keras.Input(shape=(latent_dim,))

x = layers.Dense(32 * 128 * 128)(generator_input)
x = layers.LeakyReLU()(x)
x = layers.Reshape((128, 128, 32))(x)#将输入转换成16*16 128通道的特征图

x = layers.Conv2D(32, 5, padding='same')(x)
x = layers.LeakyReLU()(x)
x = layers.Conv2D(64, 5, padding='same')(x)
x = layers.LeakyReLU()(x)

x = layers.Conv2DTranspose(64, 4, strides=4, padding='same')(x)#上采样32*32
x = layers.LeakyReLU()(x)

x = layers.Conv2D(128, 5, padding='same')(x)
x = layers.LeakyReLU()(x)
x = layers.Conv2D(128, 5, padding='same')(x)
x = layers.LeakyReLU()(x)

#产生32x32 1通道的特征图
x = layers.Conv2D(channels, 7, activation='tanh', padding='same')(x)
generator = keras.models.Model(generator_input, x)#将(latent_dim,)->(32,32,3)
generator.summary()
# Out:
# Model: "model_16"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# input_18 (InputLayer)        (None, 2)                 0
# _________________________________________________________________
# dense_15 (Dense)             (None, 524288)            1572864
# _________________________________________________________________
# leaky_re_lu_62 (LeakyReLU)   (None, 524288)            0
# _________________________________________________________________
# reshape_12 (Reshape)         (None, 128, 128, 32)      0
# _________________________________________________________________
# conv2d_51 (Conv2D)           (None, 128, 128, 32)      25632
# _________________________________________________________________
# leaky_re_lu_63 (LeakyReLU)   (None, 128, 128, 32)      0
# _________________________________________________________________
# conv2d_52 (Conv2D)           (None, 128, 128, 64)      51264
# ...

# %% [markdown]
# # D_net

# %%
discriminator_input = layers.Input(shape=(height, width, channels))
x = layers.Conv2D(64, 3)(discriminator_input)
x = layers.LeakyReLU()(x)
x = layers.Conv2D(64, 4, strides=2)(x)
x = layers.LeakyReLU()(x)
x = layers.Conv2D(128, 4, strides=2)(x)
x = layers.LeakyReLU()(x)
x = layers.Conv2D(128, 4, strides=2)(x)
x = layers.LeakyReLU()(x)
x = layers.Flatten()(x)

x = layers.Dropout(0.5)(x)

x = layers.Dense(1, activation='sigmoid')(x)#二分类

discriminator = keras.models.Model(discriminator_input, x)
discriminator.summary()

discriminator_optimizer = keras.optimizers.RMSprop(lr=0.0008,
        clipvalue=1.0,decay=1e-8)
discriminator.compile(optimizer=discriminator_optimizer,
    loss='binary_crossentropy')
# Out:
# Model: "model_17"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# input_19 (InputLayer)        (None, 512, 512, 3)       0
# _________________________________________________________________
# conv2d_56 (Conv2D)           (None, 510, 510, 64)      1792
# _________________________________________________________________
# leaky_re_lu_68 (LeakyReLU)   (None, 510, 510, 64)      0
# _________________________________________________________________
# conv2d_57 (Conv2D)           (None, 254, 254, 64)      65600
# _________________________________________________________________
# leaky_re_lu_69 (LeakyReLU)   (None, 254, 254, 64)      0
# _________________________________________________________________
# conv2d_58 (Conv2D)           (None, 126, 126, 128)     131200
# _________________________________________________________________
# leaky_re_lu_70 (LeakyReLU)   (None, 126, 126, 128)     0
# ...

# %%
discriminator.trainable = False

gan_input = keras.Input(shape=(latent_dim,))
gan_output = discriminator(generator(gan_input))
gan = keras.models.Model(gan_input,gan_output)

gan_optimizer = keras.optimizers.RMSprop(lr=0.0004,clipvalue=1.0,
        decay=1e-8)
gan.compile(optimizer=gan_optimizer,loss='binary_crossentropy')

# %% [markdown]
# # Run GAN

# %%
import os
from keras.preprocessing import image

# (x_train, y_train), (_, _) = keras.datasets.cifar10.load_data()
# x_train = x_train[y_train.flatten() == 6]#第6类

# x_train = x_train.reshape((x_train.shape[0],)+(height, width, channels)).astype('float32') / 255.

x_train = DataResize

iterations = 10000
batch_size = 4
save_dir = 'out'#保存生成图片

start = 0
for step in range(iterations):
    random_latent_vectors = np.random.normal(size=(batch_size,
        latent_dim))#正态分布随机取点

    generated_images = generator.predict(random_latent_vectors)#fake图

    stop = start + batch_size
    real_images = x_train[start: stop]
    #混合真、假图片
    combined_images = np.concatenate([generated_images, real_images])
    #标签
    labels = np.concatenate([np.ones((batch_size, 1)),
        np.zeros((batch_size, 1))])
    labels += 0.05 * np.random.random(labels.shape)#加随机噪声

    d_loss = discriminator.train_on_batch(combined_images, labels)

    random_latent_vectors = np.random.normal(size=(batch_size,
        latent_dim))
    isleading_targets = np.zeros((batch_size, 1))
    #gan训练：训练generator，固定discriminator
    misleading_targets = np.zeros((batch_size, 1))
    a_loss = gan.train_on_batch(random_latent_vectors,misleading_targets)

    start += batch_size
    if start > len(x_train) - batch_size:
        start = 0

    if step % 100 == 0:#每100步保存一次
        gan.save_weights('gan.h5')
        print('EPOCH: {}, discriminator_loss:{:.4}, generator_loss:{:.4}'.format(step, d_loss, a_loss))

        img = image.array_to_img(generated_images[0] * 255., scale=False)
        img.save(os.path.join(save_dir,'generated_frog'+str(step)+'.png'))

        img = image.array_to_img(real_images[0] * 255., scale=False)
        img.save(os.path.join(save_dir,'real_frog' + str(step) + '.png'))
# Out:
# EPOCH: 0, discriminator_loss:1.263, generator_loss:0.0002119
# /home/acd13264yb/jupyter_env/lib/python3.6/site-packages/keras/engine/training.py:493: UserWarning: Discrepancy between trainable weights and collected trainable weights, did you set `model.trainable` without calling `model.compile` after ?
#   'Discrepancy between trainable weights and collected trainable'
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-100-de8426bedeff> in <module>
#      36     #gan训练：训练generator，固定discriminator
#      37     misleading_targets = np.zeros((batch_size, 1))
# ---> 38     a_loss = gan.train_on_batch(random_latent_vectors,misleading_targets)
#      39
#      40     start += batch_size
#
# ~/jupyter_env/lib/python3.6/site-packages/keras/engine/training.py in train_on_batch(self, x, y, sample_weight, class_weight)
#    1447             ins = x + y + sample_weights
# ...

# %%
img = cv2.imread("./out/generated_frog100.png")
plt.imshow(img)
plt.show()
